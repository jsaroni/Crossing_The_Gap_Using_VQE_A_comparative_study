# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.34.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.2.1)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 52.9 MB/s eta 0:00:00
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray>=0.6.1 (from pennylane)
#   Downloading autoray-0.6.8-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.2)
# Collecting pennylane-lightning>=0.34 (from pennylane)
#   Downloading PennyLane_Lightning-0.34.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 53.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.9.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.2.2)
# Installing collected packages: semantic-version, rustworkx, autoray, pennylane-lightning, pennylane
# Successfully installed autoray-0.6.8 pennylane-0.34.0 pennylane-lightning-0.34.0 rustworkx-0.14.0 semantic-version-2.10.0

# %%
import pennylane as qml
import pennylane.numpy as np
import matplotlib.pyplot as plt

# %%
def vec_check(vec,electron_num):
    """
    To check solution conserve the charge
    """
    for i,e in enumerate(vec):
        if np.abs(e) > 1e-8:
            e_occ=bin(i)[2:]
            lst=' '.join(e_occ).split(' ')
            cv=tuple(map(int, lst))
            e_num=sum(cv)
            if e_num!=electron_num:
                return False
    return True

def exact_ch_energy(num_electrons,symbol,geometry,charge):
    Ha=qml.qchem.molecular_hamiltonian(symbol, geometry, charge=charge,\
                                               basis="STO-3G",active_electrons=num_electrons)[0]
    H_matrix=qml.matrix(Ha)
    vals, vecs = np.linalg.eigh(H_matrix)

    inds=np.argsort(vals)
    eng=vals[inds]
    vec=vecs[:,inds]
    E_collect=[0,0,0,0]
    E_collect[0]=eng[0]
    print('The ground state energy with sz=0:',eng[0])

    sz=qml.qchem.spinz(len(Ha.wires))
    SZ=qml.matrix(sz)
    Stop=[False,False,False]

    elec_num=num_electrons
    for i in range(1,len(eng)): # Finding first excited state with -1 Sz
        Sz=vec[:,i].dot(SZ.dot(np.transpose(np.conjugate(vec[:,i]))))
        if np.abs(Sz) < 1e-5 and vec_check(vec[:,i],elec_num):
            print('The first excied state energy with sz=0:',eng[i])
            Stop[0]=True
            E_collect[1]=eng[i]
        elif np.abs(Sz-1) < 1e-5 and vec_check(vec[:,i],elec_num):
            print('The first excied state energy with sz=1:',eng[i])
            Stop[1]=True
            E_collect[2]=eng[i]
        elif np.abs(Sz+1) < 1e-5 and vec_check(vec[:,i],elec_num):
            print('The first excied state energy with sz=-1:',eng[i])
            Stop[2]=True
            E_collect[3]=eng[i]
        if np.all(Stop):
            break
    return E_collect

# %%
L=1.5
symbol=["H", "Li"]
geometry=np.array([0.0, 0.0, -L/2, 0.0, 0.0, L/2])

charge=0
num_electrons=2
exact_ch_energy(num_electrons,symbol,geometry,charge)
# Out:
# The ground state energy with sz=0: -7.626624465547493
# The first excied state energy with sz=1: -7.522914627103037
# The first excied state energy with sz=0: -7.522914627103034
# The first excied state energy with sz=-1: -7.52291462710303
# [-7.626624465547493, -7.522914627103034, -7.522914627103037, -7.52291462710303]

# %%
def depth(qnode):
    def _fn(*args, **kwargs):
        qnode.construct(args, kwargs)
        return qnode.qtape.get_depth()
    return _fn

# %%
def bit_to_vec(bitstring_dict,num_qubits):
    vec=np.zeros(2**num_qubits)
    amp=0
    for i in range(2**num_qubits):
        bitstr=bin(i)[2:]
        if len(bitstr) < num_qubits:
            bitstr=(num_qubits-len(bitstr))*'0'+bitstr

        if bitstr in bitstring_dict:
            vec[i]=bitstring_dict[bitstr]
            amp+=np.abs(bitstring_dict[bitstr])**2
    vec=vec/np.sqrt(amp)
    return vec

# %%
class vqe_X_ch():
    def __init__(self,state,num_electrons,symbol,geometry,charge) -> None:
        self.num_electrons=num_electrons
        self.symbol=symbol
        self.geometry=geometry
        self.charge=charge

        self.hamiltonian=self.Ch_hamiltonian(symbol,geometry,num_electrons,charge)
        self.num_qubits = len(self.hamiltonian.wires)
        self.sz=qml.qchem.spinz(self.num_qubits)
        self.singles, self.doubles = qml.qchem.excitations(self.num_electrons, self.num_qubits)
        self.state=bit_to_vec(state,self.num_qubits)
        H_matrix=qml.matrix(self.hamiltonian)
        H_sq=H_matrix.dot(H_matrix)

        self.H_sq_ob=qml.Hermitian(H_sq, wires=range(self.num_qubits))
        self.dev = qml.device("default.qubit", wires=self.num_qubits)
        self.cost_h_fn = qml.QNode(self.circuit, self.dev)
        self.Sz_fn = qml.QNode(self.circuit_sz, self.dev)
        self.cost_hsq_fn = qml.QNode(self.circuit_h_sq, self.dev)

    def Ch_hamiltonian(self,symbol,geometry,num_electrons,charge):
        return qml.qchem.molecular_hamiltonian(symbol, geometry, charge=charge,\
                                               basis="STO-3G",active_electrons=num_electrons)[0]

    def hf(self,electrons, num_qubits):
        return qml.qchem.hf_state(electrons=electrons, orbitals=num_qubits)

    def circuit(self,state,weights):
        qml.StatePrep(state, wires=range(self.num_qubits))
        for i in range(len(self.singles)):
            qml.SingleExcitation(weights[i+len(self.doubles)], wires=self.singles[i])
        for i in range(len(self.doubles)):
            qml.DoubleExcitation(weights[i], wires=self.doubles[i])
        return qml.expval(self.hamiltonian)

    def circuit_h_sq(self,state,weights):
        qml.StatePrep(state, wires=range(self.num_qubits))
        for i in range(len(self.singles)):
            qml.SingleExcitation(weights[i+len(self.doubles)], wires=self.singles[i])
        for i in range(len(self.doubles)):
            qml.DoubleExcitation(weights[i], wires=self.doubles[i])
        return qml.expval(self.H_sq_ob)

    def circuit_sz(self,state,weights):
        qml.StatePrep(state, wires=range(self.num_qubits))
        for i in range(len(self.singles)):
            qml.SingleExcitation(weights[i+len(self.doubles)], wires=self.singles[i])
        for i in range(len(self.doubles)):
            qml.DoubleExcitation(weights[i], wires=self.doubles[i])
        return qml.expval(self.sz)

    def cost_fn(self,params):
        self.cost_hsq_fn = qml.QNode(self.circuit_h_sq, self.dev)
        return np.sqrt(self.cost_hsq_fn(self.state,params)-self.cost_h_fn(self.state,params)**2)

    def run(self,epochs=400,stepsize=0.5,cov=1e-6,print_train=True):
        opt = qml.AdamOptimizer(stepsize=stepsize)
        self.weights =np.zeros(len(self.doubles + self.singles), requires_grad=True)
        i=0
        iter=[]
        cost_val=[]
        Lowest_cost=0
        self.best_weights=self.weights

        cov=cov
        E0_pev=0
        for _ in range(epochs):
            self.weights = opt.step(self.cost_fn, self.weights)
            iter.append(i)
            cost=self.cost_fn(self.weights)
            E0=self.cost_h_fn(self.state,self.weights)

            if Lowest_cost>cost:
                Lowest_cost=cost
                self.best_weights=self.weights
            cost_val.append(E0)

            i=i+1
            if print_train:
                print('iter:',i,' E0:',E0,' Sz:',self.Sz_fn(self.state,self.weights))
            if np.abs(E0-E0_pev)<cov:
                break

            E0_pev=E0
        self.E0=E0
        return E0

# %%
L=1.5
symbol=["H", "Li"]
geometry=np.array([0.0, 0.0, -L/2, 0.0, 0.0, L/2])

charge=0
num_electrons=2
e_trial_stat_sz0={'0101000000': 1}
vqe_x_test=vqe_X_ch(e_trial_stat_sz0,num_electrons,symbol,geometry,charge)

# %%
vqe_x_test.run(stepsize=0.5)
# Out:
# iter: 1  E0: -7.517692384719897  Sz: -1.0
# iter: 2  E0: -7.514239380733699  Sz: -1.0
# iter: 3  E0: -7.518771845976776  Sz: -0.9999999999999999
# iter: 4  E0: -7.516220142977723  Sz: -1.0
# iter: 5  E0: -7.517132356342593  Sz: -0.9999999999999998
# iter: 6  E0: -7.5187728786711965  Sz: -0.9999999999999998
# iter: 7  E0: -7.516836759338113  Sz: -1.0
# iter: 8  E0: -7.5175301502878416  Sz: -1.0000000000000002
# iter: 9  E0: -7.518863284232784  Sz: -1.0
# iter: 10  E0: -7.517907378987171  Sz: -1.0
# iter: 11  E0: -7.5181185987854855  Sz: -1.0
# iter: 12  E0: -7.518862905438367  Sz: -0.9999999999999999
# iter: 13  E0: -7.518041747034343  Sz: -1.0
# iter: 14  E0: -7.517987215235522  Sz: -1.0
# iter: 15  E0: -7.518809780165736  Sz: -1.0000000000000002
# iter: 16  E0: -7.518558717096734  Sz: -0.9999999999999999
# iter: 17  E0: -7.518395615383124  Sz: -1.0000000000000002
# iter: 18  E0: -7.518845314955326  Sz: -1.0
# iter: 19  E0: -7.518542371223495  Sz: -1.0
# iter: 20  E0: -7.518298238182189  Sz: -1.0
# iter: 21  E0: -7.518762852307215  Sz: -1.0
# iter: 22  E0: -7.518770579276947  Sz: -0.9999999999999999
# iter: 23  E0: -7.518612750860899  Sz: -1.0000000000000002
# iter: 24  E0: -7.518846565393246  Sz: -0.9999999999999999
# iter: 25  E0: -7.518694696894229  Sz: -1.0
# iter: 26  E0: -7.518525858093653  Sz: -0.9999999999999998
# iter: 27  E0: -7.5188028872305885  Sz: -1.0
# iter: 28  E0: -7.5188134415743955  Sz: -0.9999999999999999
# iter: 29  E0: -7.5187455036535935  Sz: -1.0
# iter: 30  E0: -7.51886496977608  Sz: -1.0
# iter: 31  E0: -7.518717849344958  Sz: -0.9999999999999999
# iter: 32  E0: -7.518679237602811  Sz: -1.0
# iter: 33  E0: -7.5188549227254  Sz: -0.9999999999999999
# iter: 34  E0: -7.518816039040635  Sz: -1.0
# iter: 35  E0: -7.518830822256209  Sz: -0.9999999999999999
# iter: 36  E0: -7.518844910345102  Sz: -1.0
# iter: 37  E0: -7.518727091528905  Sz: -1.0
# iter: 38  E0: -7.518803244084104  Sz: -1.0
# iter: 39  E0: -7.518861969842582  Sz: -1.0
# iter: 40  E0: -7.51883477013951  Sz: -0.9999999999999999
# iter: 41  E0: -7.518864978696218  Sz: -1.0
# iter: 42  E0: -7.5187914155138325  Sz: -1.0
# iter: 43  E0: -7.518793914980031  Sz: -1.0
# iter: 44  E0: -7.518864332521255  Sz: -0.9999999999999999
# iter: 45  E0: -7.518850796482062  Sz: -1.0
# iter: 46  E0: -7.518865369232779  Sz: -1.0
# iter: 47  E0: -7.518821598077656  Sz: -0.9999999999999998
# iter: 48  E0: -7.518808204456726  Sz: -0.9999999999999999
# iter: 49  E0: -7.518861980200677  Sz: -0.9999999999999999
# iter: 50  E0: -7.518859542456055  Sz: -1.0
# iter: 51  E0: -7.51886529786218  Sz: -1.0
# iter: 52  E0: -7.5188309924236005  Sz: -1.0
# iter: 53  E0: -7.518825414331083  Sz: -1.0
# iter: 54  E0: -7.518863192684323  Sz: -1.0
# iter: 55  E0: -7.518863401087523  Sz: -1.0
# tensor(-7.5188634, requires_grad=True)

# %%
class adapt_vqe_X_ch():
    def __init__(self,state,num_electrons,symbol,geometry,charge) -> None:
        self.num_electrons=num_electrons
        self.symbol=symbol
        self.geometry=geometry
        self.charge=charge

        self.hamiltonian=self.Ch_hamiltonian(symbol,geometry,num_electrons,charge)
        self.num_qubits = len(self.hamiltonian.wires)
        self.sz=qml.qchem.spinz(self.num_qubits)
        self.singles, self.doubles = qml.qchem.excitations(self.num_electrons, self.num_qubits)
        self.state=bit_to_vec(state,self.num_qubits)
        self.pool_operators=self.singles+self.doubles
        H_matrix=qml.matrix(self.hamiltonian)
        H_sq=H_matrix.dot(H_matrix)

        self.H_sq_ob=qml.Hermitian(H_sq, wires=range(self.num_qubits))
        self.dev = qml.device("default.qubit", wires=self.num_qubits)
        self.cost_h_fn = qml.QNode(self.circuit, self.dev, expansion_strategy="device")
        self.Sz_fn = qml.QNode(self.circuit_sz, self.dev)
        self.cost_hsq_fn = qml.QNode(self.circuit_h_sq, self.dev, expansion_strategy="device")

    def Ch_hamiltonian(self,symbol,geometry,num_electrons,charge):
        return qml.qchem.molecular_hamiltonian(symbol, geometry, charge=charge,\
                                               basis="STO-3G",active_electrons=num_electrons)[0]

    def hf(self,electrons,num_qubits):
        return qml.qchem.hf_state(electrons=electrons, orbitals=num_qubits)

    def circuit(self,state,weights,ops_cir):
        qml.StatePrep(state, wires=range(self.num_qubits))
        for i, excitation in enumerate(ops_cir):
            if len(excitation) == 4:
                qml.DoubleExcitation(weights[i], wires=excitation)
            else:
                qml.SingleExcitation(weights[i], wires=excitation)
        return qml.expval(self.hamiltonian)

    def circuit_h_sq(self,state,weights,ops_cir):
        qml.StatePrep(state, wires=range(self.num_qubits))
        for i, excitation in enumerate(ops_cir):
            if len(excitation) == 4:
                qml.DoubleExcitation(weights[i], wires=excitation)
            else:
                qml.SingleExcitation(weights[i], wires=excitation)
        return qml.expval(self.H_sq_ob)

    def circuit_sz(self,state,weights,ops_cir):
        qml.StatePrep(state, wires=range(self.num_qubits))
        for i, excitation in enumerate(ops_cir):
            if len(excitation) == 4:
                qml.DoubleExcitation(weights[i], wires=excitation)
            else:
                qml.SingleExcitation(weights[i], wires=excitation)
        return qml.expval(self.sz)

    def cost_fn(self,params,ops_cir):
        self.cost_hsq_fn = qml.QNode(self.circuit_h_sq, self.dev)
        return np.sqrt(self.cost_hsq_fn(self.state,params,ops_cir)-self.cost_h_fn(self.state,params,ops_cir)**2)

    def run(self,epochs=400,stepsize=0.5,cov=1e-6,print_train=True,ep=10,threshold=0.05):
        opt = qml.GradientDescentOptimizer(stepsize=stepsize)

        self.ops_cir=[]# doubles_select+singles_select

        weights = []
        self.weights=np.array(weights)
        circuit_gradient = qml.grad(self.cost_fn, argnum=0)

        E0 = self.cost_h_fn(self.state,self.weights, self.ops_cir)
        print(f"Epoch = 0, G Energy = {E0:.8f} Ha")

        i=0
        iter=[]
        cost_val=[]
        Lowest_cost=0
        self.best_weights=self.weights

        cov=cov
        E0_pev=0
        for n in range(epochs):

            Test_set=self.ops_cir+self.pool_operators
            Test_params=list(self.weights)+[0.0]*len(self.pool_operators)
            Test_params=np.array(Test_params)

            test_grads = circuit_gradient(Test_params,Test_set)
            test_grads = test_grads[len(self.weights):]
            maxpos = np.argmax(np.abs(test_grads))

            if n<= ep or np.abs(test_grads[maxpos])<threshold:

                max_op=self.pool_operators[maxpos]
                self.ops_cir.append(max_op)
                self.weights=np.append(self.weights, 0.0)

            self.weights,_ = opt.step(self.cost_fn, self.weights,self.ops_cir) # Step 11.
            E0 = self.cost_h_fn(self.state,self.weights,self.ops_cir)

            print(f"Epoch = {n+1}, G Energy ={E0:.8f} Ha, Sz ={self.Sz_fn(self.state,self.weights,self.ops_cir):.8f}")
            print("Number of gates = {}\n".format(len(self.ops_cir)))
            if np.abs(E0-E0_pev)<cov:
                break
            E0_pev=E0
        self.E0=E0
        return E0

# %%
L=1.5
symbol=["H", "Li"]
geometry=np.array([0.0, 0.0, -L/2, 0.0, 0.0, L/2])

charge=0
num_electrons=2
e_trial_stat_sz0={'1100000000': 1}
adapt_vqe_x_test=adapt_vqe_X_ch(e_trial_stat_sz0,num_electrons,symbol,geometry,charge)

# %%
adapt_vqe_x_test.run(stepsize=0.07,ep=10,threshold=0.05)
# Out:
# Epoch = 0, G Energy = -7.60898166 Ha
# Epoch = 1, G Energy =-7.61316842 Ha, Sz =0.00000000
# Number of gates = 1
#
# Epoch = 2, G Energy =-7.61890204 Ha, Sz =0.00000000
# Number of gates = 2
#
# Epoch = 3, G Energy =-7.62166321 Ha, Sz =0.00000000
# Number of gates = 3
#
# Epoch = 4, G Energy =-7.62203569 Ha, Sz =0.00000000
# Number of gates = 4
#
# Epoch = 5, G Energy =-7.62265654 Ha, Sz =0.00000000
# Number of gates = 5
#
# Epoch = 6, G Energy =-7.62327613 Ha, Sz =0.00000000
# Number of gates = 6
#
# Epoch = 7, G Energy =-7.62387831 Ha, Sz =-0.00000000
# Number of gates = 7
#
# Epoch = 8, G Energy =-7.62462708 Ha, Sz =0.00000000
# Number of gates = 8
#
# Epoch = 9, G Energy =-7.62543952 Ha, Sz =0.00000000
# Number of gates = 9
#
# Epoch = 10, G Energy =-7.62603629 Ha, Sz =-0.00000000
# Number of gates = 10
#
# Epoch = 11, G Energy =-7.62630016 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 12, G Energy =-7.62630826 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 13, G Energy =-7.62421967 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 14, G Energy =-7.62582104 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 15, G Energy =-7.62432974 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 16, G Energy =-7.62577069 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 17, G Energy =-7.62441334 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 18, G Energy =-7.62572607 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 19, G Energy =-7.62448470 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 20, G Energy =-7.62568544 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 21, G Energy =-7.62454687 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 22, G Energy =-7.62564821 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 23, G Energy =-7.62460169 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 24, G Energy =-7.62561395 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 25, G Energy =-7.62465046 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 26, G Energy =-7.62558230 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 27, G Energy =-7.62469413 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 28, G Energy =-7.62555300 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 29, G Energy =-7.62473346 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 30, G Energy =-7.62552581 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 31, G Energy =-7.62476903 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 32, G Energy =-7.62550054 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 33, G Energy =-7.62480133 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 34, G Energy =-7.62547703 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 35, G Energy =-7.62483074 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 36, G Energy =-7.62545514 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 37, G Energy =-7.62485759 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 38, G Energy =-7.62543475 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 39, G Energy =-7.62488216 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 40, G Energy =-7.62541573 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 41, G Energy =-7.62490470 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 42, G Energy =-7.62539799 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 43, G Energy =-7.62492539 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 44, G Energy =-7.62538143 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 45, G Energy =-7.62494443 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 46, G Energy =-7.62536598 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 47, G Energy =-7.62496196 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 48, G Energy =-7.62535156 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 49, G Energy =-7.62497812 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 50, G Energy =-7.62533810 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 51, G Energy =-7.62499304 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 52, G Energy =-7.62532554 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 53, G Energy =-7.62500683 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 54, G Energy =-7.62531380 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 55, G Energy =-7.62501957 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 56, G Energy =-7.62530285 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 57, G Energy =-7.62503135 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 58, G Energy =-7.62529262 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 59, G Energy =-7.62504227 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 60, G Energy =-7.62528308 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 61, G Energy =-7.62505237 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 62, G Energy =-7.62527417 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 63, G Energy =-7.62506174 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 64, G Energy =-7.62526585 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 65, G Energy =-7.62507042 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 66, G Energy =-7.62525809 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 67, G Energy =-7.62507847 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 68, G Energy =-7.62525084 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 69, G Energy =-7.62508594 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 70, G Energy =-7.62524408 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 71, G Energy =-7.62509288 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 72, G Energy =-7.62523777 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 73, G Energy =-7.62509931 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 74, G Energy =-7.62523188 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 75, G Energy =-7.62510529 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 76, G Energy =-7.62522639 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 77, G Energy =-7.62511084 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 78, G Energy =-7.62522126 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 79, G Energy =-7.62511600 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 80, G Energy =-7.62521649 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 81, G Energy =-7.62512079 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 82, G Energy =-7.62521203 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 83, G Energy =-7.62512525 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 84, G Energy =-7.62520787 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 85, G Energy =-7.62512939 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 86, G Energy =-7.62520399 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 87, G Energy =-7.62513324 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 88, G Energy =-7.62520038 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 89, G Energy =-7.62513682 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 90, G Energy =-7.62519701 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 91, G Energy =-7.62514015 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 92, G Energy =-7.62519386 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 93, G Energy =-7.62514324 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 94, G Energy =-7.62519093 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 95, G Energy =-7.62514612 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 96, G Energy =-7.62518820 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 97, G Energy =-7.62514880 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 98, G Energy =-7.62518565 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 99, G Energy =-7.62515129 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 100, G Energy =-7.62518328 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 101, G Energy =-7.62515361 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 102, G Energy =-7.62518107 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 103, G Energy =-7.62515576 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 104, G Energy =-7.62517900 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 105, G Energy =-7.62515777 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 106, G Energy =-7.62517708 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 107, G Energy =-7.62515964 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 108, G Energy =-7.62517529 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 109, G Energy =-7.62516138 Ha, Sz =-0.00000000
# Number of gates = 11
#
# Epoch = 110, G Energy =-7.62517362 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 111, G Energy =-7.62516300 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 112, G Energy =-7.62517207 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 113, G Energy =-7.62516450 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 114, G Energy =-7.62517062 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 115, G Energy =-7.62516590 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 116, G Energy =-7.62516927 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 117, G Energy =-7.62516721 Ha, Sz =0.00000000
# Number of gates = 11
#
# Epoch = 118, G Energy =-7.62516801 Ha, Sz =0.00000000
# Number of gates = 11
# tensor(-7.62516801, requires_grad=True)
